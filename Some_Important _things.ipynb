# %% [markdown]
# # **Artificiall Intelligence**
#
#  Artificial Intelligence is the branch of computer science concerned with development of
#  methods that allow computers to learn without explicit programming.
#
# - ### **Types Of Artificiall Intelligence**
#
# 1) **Narrow AI** (Smart Speakers,Autonumous Cars,Chat Gpt etc)
# 2) **General AI**(Do anything a human can do)
#
# - ### **Most Popular Way to Do Al**
# #####  **Machine Learning**
#
#  Machine Learning is a branch of Al, which focuses on methods, that can learn from examples and experience instead of relying on hard- coded rules and make predictions on new data.
#
#
#       RULES -----------------|------------------|\
#                              |                  | \
#                              |   Classical      |  |>----------------Answers
#                              |       AI         | /
#       Data ------------------|------------------|/
#
#
#       Answers----------------|------------------|\
#                              |                  | \
#                              |     Machine      |  |>----------------Rules
#                              |     Learning     | /
#       Data ------------------|------------------|/
#
#
# ##### **Machine Learning Types**
#
# 1) **Supervises ML**(Learning with labled Data)
#       > Supervised learning is a type of AI learning that requires labeled inputs and corresponding outputs.The input data in supervised learning is accompanied by labels or classes.Supervised learning is used in various applications such as speech recognition and filtering.
#      - Classification.
#      - Regression(Prediction).
# 2) **Unsupervises ML**(Learning with unlabled Data)
#      - Clustering.
#      - Anomaly Detection.
#      - Dimentionally Reduction.
# 3) **Reinforcement Learning**(Learn to act based on Feedback/Reward)

# %% [markdown]
# **Hallucination**\
# Hallucination in the context of language models refers to the generation of text or responses that seem syntactically sound, fluent, and natural but are factually incorrect, nonsensical, or unfaithful to the provided source input.
#
# **Baby Agi**\

# %% [markdown]
# # **Introduction to ChatGPT**
# - ChatGPT stands for Generative Pretrained Transformer.
# - ChatGPT is an advanced Al language model developed by OpenAl.
# - ChatGPT revolutionizes Natural Language Processing'
#
# # **Promt Engineering**
#
# - Prompt engineering involves crafting tailored instructions or queries to guide the language model towards desired outputs.
# - It helps shape the behavior of the model and improves response quality.
#
# # **Anatomy of Prompt**
#
# In the context of language models, a prompt refers to the input or instruction provided to the
# model to generate a specific response or output.
#
# **Parts of a Good Prompt (Not all are necessary for each and every prompt.)**
#
# 1) Simulate Persona
# 2) Task
# 3) Steps to complete Task
# 4) Context/Constraints
# 5) Goal
# 6) Format Output
#
# **Importance of Prompt Engineering**
#
# - Ensures accurate and relevant responses.
# - Mitigates bias and promotes ethical use of Al.
# - Helps avoid undesired or harmful outputs.
# - Enables control over chatbot behavior

# %% [markdown]
# Every Langauge modal has 2 things .
#
# - Encoder.
# - Decoder.
#
#
#                                        |-------------|
#         Human Langauge Representaion ->|   Encoder   |->Machine Langauge Representaion
#                                        |-------------|
#
#                                          |-------------|
#         Machine Langauge Representaion ->|   Decoder   |->Human Langauge Representaion
#                                          |-------------|
#
#
#
#
# # **Generative Modals**
#
#
#
# - **`Generative Modals are decoder part of transformers.`**
#
# - **Auto Encoders**
# - **Gen(Genrative Adversal Network)**
# - **LLM(Large Language Modals)**
# - **Diffusion Modals.**
# - **Transformer Neural Network.**
#
#
#
#
# Large langauge Modals need Numerical Representations.
